# %%
import pandas as pd
import numpy as np

from tqdm import tqdm_notebook as tqdm
from tqdm._tqdm_notebook import tqdm_notebook
tqdm_notebook.pandas(desc="hoge progress: ")

# %%
trn_df = pd.read_csv('../mnt/inputs/origin/train.csv.zip')
trn_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250   ...      4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514   ...     -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
trn_df.progress_apply(lambda row: np.prod(row[2:])**(1/len(row[2:])), axis=1)
# Out:
# ...
# 0                            (6.396767858034709+0j)
# 1           (6.379682642135789+0.1002200635092643j)
# 2                           (5.8512374904860405+0j)
# 3          (6.155675355000754+0.09670107584129851j)
# 4          (6.183925710663796+0.09714486789139358j)
# 5                            (6.129659389502623+0j)
# 6                            (6.307928558121277+0j)
# 7                            (5.731667361525333+0j)
# 8                            (5.772165572268043+0j)
# 9                            (5.917382126984576+0j)
# 10                           (6.013416233331365+0j)
# 11         (5.793298980232632+0.09100841284680201j)
# 12                           (6.246163130958276+0j)
# 13         (5.939394624918369+0.09330346663084567j)
# 14                           (6.636950959361903+0j)
# 15                          (5.7247299164623655+0j)
# 16                           (5.858331045244093+0j)
# 17                           (6.049677461597071+0j)
# ...

# %%
trn_df.progress_apply(lambda row: np.linalg.norm(row[2:]), axis=1)
# Out:
# ...
# 0         167.130979
# 1         176.851773
# 2         151.482195
# 3         163.140653
# 4         185.801323
# 5         159.228510
# 6         168.537453
# 7         164.478185
# 8         169.232055
# 9         167.825144
# 10        165.512290
# 11        154.117424
# 12        169.835436
# 13        161.505561
# 14        175.221288
# 15        154.476990
# 16        161.400670
# 17        163.448033
# 18        169.515796
# 19        170.835194
# 20        161.813164
# 21        170.675031
# 22        177.855596
# 23        164.664064
# 24        172.921559
# 25        174.087307
# 26        177.120166
# 27        173.723272
# 28        158.470080
# 29        159.783679
#              ...
# 199970    159.838037
# 199971    171.734909
# 199972    169.284317
# 199973    171.452942
# 199974    166.200329
# 199975    163.402566
# 199976    155.772907
# 199977    168.804672
# 199978    163.657341
# 199979    173.789641
# 199980    161.979669
# 199981    167.079328
# ...
